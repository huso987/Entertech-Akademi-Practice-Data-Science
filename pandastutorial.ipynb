# %%
import pandas as pd
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
# verson kontrolu
print(pd.__version__)
# Out:
# 2.1.3

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
b = [3, 1, 4]
myvar = pd.Series(b)
print(myvar)
# Out:
# 0    3
# 1    1
# 2    4
# dtype: int64

# %%
print(myvar[0])
# Out:
# 3

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ['x', 'y', 'z'])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar['y'])
# Out:
# 7

# %%
calories = {"day1": 402, "day2": 400, "day3": 404}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    402
# day2    400
# day3    404
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data = {
    "calories": [420, 410, 390],
    "duration": [50, 36, 42]
}
df = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       410        36
# 2       390        42

# %%
# loc()  etiket tabanlı indexleme , ayırma
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       410        36

# %%
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       410        36
# day3       390        42

# %%
print(pd.DataFrame(df.loc["day2"]))
# Out:
#           day2
# calories   410
# duration    36

# %%
data = pd.read_csv("MOCK_DATA.csv")
print(data)
# Out:
#        id first_name  last_name                       email       gender  \
# 0       1    Marilyn    Hartley       mhartley0@youtube.com       Female
# 1       2   Sheelagh     Florey            sflorey1@last.fm       Female
# 2       3      Conan  MacKeague    cmackeague2@geocities.jp         Male
# 3       4     Berthe      Elder        belder3@yolasite.com       Female
# 4       5     Jessie     Leaney   jleaney4@sciencedaily.com  Genderqueer
# ..    ...        ...        ...                         ...          ...
# 995   996     Farica    Barlass       fbarlassrn@flavors.me  Genderqueer
# 996   997      Shane       Coen      scoenro@friendfeed.com         Male
# 997   998      Paolo    Waiting  pwaitingrp@tripadvisor.com         Male
# 998   999      Cathe    Godbert         cgodbertrq@ox.ac.uk       Female
# 999  1000      Gabby       Blay            gblayrr@ox.ac.uk         Male
#
#          ip_address
# 0      252.94.0.251
# 1    165.34.214.246
# 2    18.118.239.148
# ...

# %%
print(data.to_string)
# Out:
# <bound method DataFrame.to_string of        id first_name  last_name                       email       gender  \
# 0       1    Marilyn    Hartley       mhartley0@youtube.com       Female
# 1       2   Sheelagh     Florey            sflorey1@last.fm       Female
# 2       3      Conan  MacKeague    cmackeague2@geocities.jp         Male
# 3       4     Berthe      Elder        belder3@yolasite.com       Female
# 4       5     Jessie     Leaney   jleaney4@sciencedaily.com  Genderqueer
# ..    ...        ...        ...                         ...          ...
# 995   996     Farica    Barlass       fbarlassrn@flavors.me  Genderqueer
# 996   997      Shane       Coen      scoenro@friendfeed.com         Male
# 997   998      Paolo    Waiting  pwaitingrp@tripadvisor.com         Male
# 998   999      Cathe    Godbert         cgodbertrq@ox.ac.uk       Female
# 999  1000      Gabby       Blay            gblayrr@ox.ac.uk         Male
#
#          ip_address
# 0      252.94.0.251
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 9999
data = pd.read_csv("MOCK_DATA.csv")
print(data)
# Out:
#        id    first_name       last_name  \
# 0       1       Marilyn         Hartley
# 1       2      Sheelagh          Florey
# 2       3         Conan       MacKeague
# 3       4        Berthe           Elder
# 4       5        Jessie          Leaney
# 5       6        Marita      Santacrole
# 6       7         Karin          Hessle
# 7       8        Chanda         Coltart
# 8       9         Teena       Spellacey
# 9      10       Vasilis           Carss
# 10     11        Nalani           Paula
# 11     12      Patrizio       Emanuelov
# 12     13        Carter           Kyles
# 13     14     Remington           Porch
# 14     15       Nicolai         Sidnell
# 15     16         Kayne            Nuss
# 16     17       Diahann     Kitchingham
# 17     18       Valaree       Paddemore
# 18     19        Mariel      Somerfield
# 19     20      Harcourt       Petracchi
# 20     21         Brady          Corcut
# 21     22       Forster       Gilhouley
# ...

# %%
#head() kullanımı
print(data.head(10))
# Out:
#    id first_name   last_name                      email       gender  \
# 0   1    Marilyn     Hartley      mhartley0@youtube.com       Female
# 1   2   Sheelagh      Florey           sflorey1@last.fm       Female
# 2   3      Conan   MacKeague   cmackeague2@geocities.jp         Male
# 3   4     Berthe       Elder       belder3@yolasite.com       Female
# 4   5     Jessie      Leaney  jleaney4@sciencedaily.com  Genderqueer
# 5   6     Marita  Santacrole  msantacrole5@engadget.com       Female
# 6   7      Karin      Hessle        khessle6@paypal.com       Female
# 7   8     Chanda     Coltart      ccoltart7@foxnews.com       Female
# 8   9      Teena   Spellacey        tspellacey8@ibm.com       Female
# 9  10    Vasilis       Carss      vcarss9@posterous.com         Male
#
#        ip_address
# 0    252.94.0.251
# 1  165.34.214.246
# 2  18.118.239.148
# 3   82.87.245.215
# 4  149.128.97.136
# 5  182.39.249.130
# 6    9.159.70.225
# 7    125.113.0.67
# 8    23.225.89.44
# ...

# %%
# head() içine birşey yazmazsan 5 sıra veri döner 
print(data.head())
# Out:
#    id first_name  last_name                      email       gender  \
# 0   1    Marilyn    Hartley      mhartley0@youtube.com       Female
# 1   2   Sheelagh     Florey           sflorey1@last.fm       Female
# 2   3      Conan  MacKeague   cmackeague2@geocities.jp         Male
# 3   4     Berthe      Elder       belder3@yolasite.com       Female
# 4   5     Jessie     Leaney  jleaney4@sciencedaily.com  Genderqueer
#
#        ip_address
# 0    252.94.0.251
# 1  165.34.214.246
# 2  18.118.239.148
# 3   82.87.245.215
# 4  149.128.97.136

# %%
# tail()  sondan verileri listeler tail() içine birşey yazmasan 5 tane döner
print(data.tail())
# Out:
#        id first_name last_name                       email       gender  \
# 995   996     Farica   Barlass       fbarlassrn@flavors.me  Genderqueer
# 996   997      Shane      Coen      scoenro@friendfeed.com         Male
# 997   998      Paolo   Waiting  pwaitingrp@tripadvisor.com         Male
# 998   999      Cathe   Godbert         cgodbertrq@ox.ac.uk       Female
# 999  1000      Gabby      Blay            gblayrr@ox.ac.uk         Male
#
#          ip_address
# 995  118.130.15.130
# 996  115.156.193.62
# 997  10.186.181.108
# 998   36.101.24.176
# 999    127.16.76.56

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None

# %%
new_df = data.dropna()
print(new_df.to_string())
# Out:
#        id    first_name       last_name                                   email       gender       ip_address
# 0       1       Marilyn         Hartley                   mhartley0@youtube.com       Female     252.94.0.251
# 1       2      Sheelagh          Florey                        sflorey1@last.fm       Female   165.34.214.246
# 2       3         Conan       MacKeague                cmackeague2@geocities.jp         Male   18.118.239.148
# 3       4        Berthe           Elder                    belder3@yolasite.com       Female    82.87.245.215
# 4       5        Jessie          Leaney               jleaney4@sciencedaily.com  Genderqueer   149.128.97.136
# 5       6        Marita      Santacrole               msantacrole5@engadget.com       Female   182.39.249.130
# 6       7         Karin          Hessle                     khessle6@paypal.com       Female     9.159.70.225
# ...

# %%
data.dropna(inplace = True)
print(data.to_string())
# Out:
#        id    first_name       last_name                                   email       gender       ip_address
# 0       1       Marilyn         Hartley                   mhartley0@youtube.com       Female     252.94.0.251
# 1       2      Sheelagh          Florey                        sflorey1@last.fm       Female   165.34.214.246
# 2       3         Conan       MacKeague                cmackeague2@geocities.jp         Male   18.118.239.148
# 3       4        Berthe           Elder                    belder3@yolasite.com       Female    82.87.245.215
# 4       5        Jessie          Leaney               jleaney4@sciencedaily.com  Genderqueer   149.128.97.136
# 5       6        Marita      Santacrole               msantacrole5@engadget.com       Female   182.39.249.130
# 6       7         Karin          Hessle                     khessle6@paypal.com       Female     9.159.70.225
# ...

# %%
tag = data.fillna(130, inplace = True)
print(tag)
# Out:
# None

# %%
a = df["calories"].fillna(130, inplace = True)
print(a)
# Out:
# None

# %%
x = df["calories"].mean()
print(x)
# Out:
# 406.6666666666667

# %%
x = df["calories"].median()
print(x)
# Out:
# 410.0

# %%
x = df["calories"].mode()[0]
print(x)
# Out:
# 390

# %%
isim = data[["first_name"]]
soyad = data[["last_name"]]
ad_soyad = data[["first_name", "last_name"]]
print(ad_soyad)
# Out:
#        first_name       last_name
# 0         Marilyn         Hartley
# 1        Sheelagh          Florey
# 2           Conan       MacKeague
# 3          Berthe           Elder
# 4          Jessie          Leaney
# 5          Marita      Santacrole
# 6           Karin          Hessle
# 7          Chanda         Coltart
# 8           Teena       Spellacey
# 9         Vasilis           Carss
# 10         Nalani           Paula
# 11       Patrizio       Emanuelov
# 12         Carter           Kyles
# 13      Remington           Porch
# 14        Nicolai         Sidnell
# 15          Kayne            Nuss
# 16        Diahann     Kitchingham
# 17        Valaree       Paddemore
# 18         Mariel      Somerfield
# 19       Harcourt       Petracchi
# 20          Brady          Corcut
# 21        Forster       Gilhouley
# 22         Aubine           Lande
# 23        Ladonna         Moresby
# 24         Daphna            Puig
# 25        Michele        McOrkill
# ...

# %%
cinsiyet = data.iloc[:,4:5].values
print(cinsiyet)
# Out:
# [['Female']
#  ['Female']
#  ['Male']
#  ['Female']
#  ['Genderqueer']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Female']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Bigender']
#  ['Male']
#  ['Female']
#  ['Polygender']
#  ['Polygender']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Male']
#  ['Male']
#  ['Genderqueer']
#  ['Genderfluid']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Non-binary']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Male']
#  ['Female']
#  ['Male']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Female']
#  ['Male']
# ...
